# %% [markdown]
# # 生成数据集

# %%
# %matplotlib inline
import torch
from IPython import display
from matplotlib import pyplot as plt
import numpy as np
import random

# %%
num_inputs = 2
num_examples = 1000
true_w = [2,-3.4]
true_b = 4.2
features = torch.randn(num_examples, num_inputs, dtype = torch.float32)

labels = true_w[0] * features[:, 0] + true_w[1] * features[:, 1] + true_b
# 添加噪声（噪声符合均值为0，标准差为0.01的正态分布）
# tensor()将numpy数组转换为Tensor对象
labels += torch.tensor(np.random.normal(0,0.01, size = labels.size()), dtype = torch.float32)

print(features[0],labels[0])
print(labels)
# Out:
# tensor([-0.0156, -0.4546]) tensor(5.7067)
# tensor([ 5.7067e+00,  6.2659e+00,  6.6024e+00,  4.5683e+00,  6.5700e+00,
#          2.4198e+00,  6.0380e+00,  5.6435e+00,  2.9956e-01,  1.3642e+01,
#          7.0248e+00,  3.2215e+00,  1.3118e+01,  4.2278e+00, -3.4970e+00,
#          5.7657e+00,  2.1121e+00,  1.2118e+01,  3.3929e+00,  7.6790e+00,
#          5.4692e+00, -3.3737e+00,  2.4598e+00,  2.3571e+00,  1.8740e+00,
#          3.0965e+00,  7.7272e+00,  5.8301e+00,  6.8183e+00,  1.2890e+01,
#          8.5005e+00, -1.4831e+00,  8.1295e+00,  4.5257e+00,  8.6358e+00,
#          4.2212e-01,  5.0671e+00,  3.6625e+00,  1.4997e+00,  3.1798e+00,
#          2.1729e+00,  1.7049e+00,  1.0355e+01,  4.1743e+00,  4.0422e+00,
#          3.6048e+00,  3.6949e+00,  1.0065e+00,  3.5096e+00,  1.0529e+01,
#          6.0150e-02,  1.6302e+00,  3.5856e-01,  7.1817e+00,  5.5587e+00,
#          7.8841e+00, -8.6000e-01,  4.9099e+00,  2.7425e+00, -4.8001e+00,
#          3.0741e+00,  3.9829e+00,  6.5897e+00,  5.8978e+00,  4.9350e+00,
#         -2.1745e+00,  5.9301e+00,  9.4208e+00,  1.6674e+00,  2.4333e+00,
#          1.4195e+00,  4.0270e+00,  2.5380e-01,  1.8916e+00, -2.8318e+00,
#         -5.5195e+00,  1.6947e+00, -2.3255e+00,  6.3922e+00,  6.8850e+00,
#          4.6064e+00,  8.2414e+00,  5.9701e+00,  2.8371e+00, -7.1499e-01,
#          1.9204e+00,  6.4797e+00,  2.2673e+00,  3.3641e-01,  4.9380e+00,
#          5.8817e+00,  4.8640e+00,  7.9893e-01,  2.3225e+00,  2.3426e+00,
#          6.6084e+00,  6.6550e+00,  1.4985e+00,  1.6280e+00,  8.7217e+00,
#          8.8211e+00,  2.5383e+00,  3.0498e+00, -7.6288e-01, -5.4002e-01,
#          6.6540e+00,  4.2181e+00,  1.0209e+01,  1.7636e-02,  6.5250e+00,
#          4.9997e+00,  3.6949e+00,  9.4818e+00,  3.9744e+00, -6.2875e-01,
#          5.2179e+00,  7.2447e+00,  6.8386e+00,  1.3882e+00,  2.8876e+00,
#          5.0309e+00,  2.6550e-01, -1.8644e+00,  8.1112e+00,  8.0327e+00,
#          6.0466e+00, -1.3117e+00, -5.7592e-01,  3.7603e+00, -4.2944e+00,
#          1.8784e+00,  8.2888e+00, -3.9789e-01, -2.3543e+00,  3.9968e+00,
#          3.1160e+00,  6.1677e+00,  6.0570e+00,  5.0019e+00,  1.4006e+00,
#         -4.1215e+00,  6.4532e+00,  5.9003e+00,  8.6381e+00,  4.1538e+00,
    use_svg_display()
    plt.rcParams['figure.figsize'] = figsize

set_figsize()
plt.scatter(features[:, 1].numpy(), labels.numpy(), 1)

# %% [markdown]
# # 读取数据

# %%
# 每次返回批量大小个随机样本的特征和标签
def data_iter(batch_size , features, labels):
    num_examples = len(features)
    indices = list(range(num_examples))
    random.shuffle(indices) # 样本读取顺序随机
    for i in range(0, num_examples, batch_size):
        j = torch.LongTensor(indices[i: min(i + batch_size, num_examples)]) #最后一次可能返回的不是完整的批量大小
        yield features.index_select(0, j), labels.index_select(0,j)

# %%
batch_size = 10
for X,y in data_iter(batch_size, features, labels):
    print(X,y)
    brea
# Out:
# tensor([[ 0.1397, -0.1404],
#         [ 1.1264, -0.4284],
#         [-1.2056,  1.9479],
#         [-0.0083,  0.6453],
#         [-0.2232, -0.3676],
#         [-0.9270, -0.2838],
#         [-0.4952,  0.1076],
#         [-1.5358, -1.8704],
#         [ 1.2030, -0.1674],
#         [-0.3360,  0.3565]]) tensor([ 4.9718,  7.9062, -4.8315,  1.9730,  5.0084,  3.3093,  2.8371,  7.4865,
#          7.1778,  2.3198])

# %% [markdown]
# # 初始化模型参数

# %%
w = torch.tensor(np.random.normal(0, 0.01, (num_inputs, 1)), dtype = torch.float32)
b = torch.zeros(1,dtype = torch.float32)
print(b)
# Out:
# tensor([0.])

# %%
#之后的模型训练中，需要对这些参数求梯度来迭代参数的值，
# 因此我们要让它们的requires_grad=True。
w.requires_grad_(requires_grad = True)
b.requires_grad_(requires_grad = True)
# Out:
# tensor([0.], requires_grad=True)

# %% [markdown]
# # 定义模型

# %%
def linerReg(X, w, b):
    return torch.mm(X, w) + b # mm函数做矩阵乘法

# %% [markdown]
# # 定义损失函数

# %%
def squared_loss(y,y_hat):
    return (y_hat - y.view(y_hat.size())) **2 / 2 #将真实值y变形成y_hat的形状

# %% [markdown]
# # 定义优化算法

# %%
def sgd(params, lr, batch_size):
    for param in params:
        param.data -= lr * param.grad / batch_size # 注意这里更改param时用的param.data

# %% [markdown]
# # 训练模型

# %%
lr = 0.03
num_epochs = 3
net = linerReg
loss = squared_loss

for epoch in range(num_epochs):
    for X, y in data_iter(batch_size,features, labels):
        l = loss(net(X, w, b), y).sum() #小批量损失
        l.backward() #小批量的损失对模型的参数求梯度
        sgd([w,b], lr ,batch_size)
        
        #不要忘了梯度清零
        w.grad.data.zero_()
        b.grad.data.zero_()
        
    train_loss = loss(net(features, w, b), labels)
    print('epoch %d, loss %f' % (epoch + 1, train_loss.mean().item()))
# Out:
# epoch 1, loss 0.000049
# epoch 2, loss 0.000049
# epoch 3, loss 0.000049

# %%
print(w,b) 
print(true_w,true_b)
#已经非常接近真实参数值：[2,-3.4] 和4.2
# Out:
# tensor([[ 1.9999],
#         [-3.3994]], requires_grad=True) tensor([4.1998], requires_grad=True)
# [2, -3.4] 4.2

# %% [markdown]
# # 简洁实现版本:

# %%
num_inputs = 2
num_examples = 1000
true_w = [2, -3.4]
true_b = 4.2
features = torch.tensor(np.random.normal(0, 1, (num_examples, num_inputs)), dtype=torch.float)
labels = true_w[0] * features[:, 0] + true_w[1] * features[:, 1] + true_b
labels += torch.tensor(np.random.normal(0, 0.01, size=labels.size()), dtype=torch.float)

# %% [markdown]
# ## 读取数据：torch.utils.data

# %%
import torch.utils.data as Data

batch_size = 10
dataSet = Data.TensorDataset(features,labels) # 将训练数据的特征和标签组合
data_iter = Data.DataLoader(dataSet, batch_size, shuffle=True)

for X, y in data_iter:
    print(X,y)
    break
# Out:
# tensor([[-1.3047, -1.2238],
#         [ 0.6478,  1.0844],
#         [-0.9540,  1.0839],
#         [-0.2459,  0.0629],
#         [ 0.2547,  1.3540],
#         [ 0.3613,  0.6831],
#         [-1.0134,  0.7148],
#         [ 0.3389,  0.8437],
#         [-0.0419,  0.1313],
#         [-1.4616,  0.6134]]) tensor([ 5.7521,  1.8157, -1.3858,  3.4893,  0.1059,  2.5852, -0.2592,  1.9968,
#          3.6838, -0.8088])

# %% [markdown]
# ## 实现线性回归模型：nn.Module

# %%
# nn的核心数据结构是Module，它是一个抽象概念
# Module可以表示某个层，或者表示一个包含很多层的神经网络
# 撰写自己的网络，一个nn.Module实例应该包含一些层，以及返回输出的前向传播方法

import torch.nn as nn
class LinearNet(nn.Module):
    def __init__(self, n_features):
        super(LinearNet, self).__init__()
        self.linear = nn.Linear(n_features, 1)
    
    def forward(self, x):
        y = self.linear(x)
        return y

net = LinearNet(num_inputs)
print(net)

# %% [markdown]
# ### 使用nn.Sequential实现线性回归模型

# %%
#nn.Sequential写法1
net = nn.Sequential(
        nn.Linear(num_inputs, 1)
        #还可以传入其他层
)

#nn.Sequential写法2
net = nn.Sequential()
net.add_module('linear', nn.Linear(num_inputs, 1))

##nn.Sequential写法3
from collections import OrderedDict
net = nn.Sequential(OrderedDict([
    ('Linear', nn.Linear(num_inputs, 1))
    # ...
]))

# %%
#查看模型的所有可学习参数，此函数返回一个生成器
for param in net.parameters():
    print(param)
# Out:
# Parameter containing:
# tensor([[-0.2190, -0.6882]], requires_grad=True)
# Parameter containing:
# tensor([-0.2463], requires_grad=True)

# %% [markdown]
# ## 初始化模型参数：torch.nn.init

# %%
#使用PyTorch的init模块的初始化方法
from torch.nn import init

init.normal_(net[0].weight, mean = 0, std = 0.01) # 均值0，标准差为0.01的正态分布
init.constant_(net[0].bias, val = 0)
# net[0]这种访问子模块的写法，只有在net是一个ModuleList或者Squential实例时才可以
# Out:
# Parameter containing:
# tensor([0.], requires_grad=True)

# %% [markdown]
# ## 定义损失函数

# %%
# nn模块提供了各种损失函数，损失函数可以看做一种特殊的层。
loss = nn.MSELoss()

# %% [markdown]
# ## 定义优化算法： torch.optim

# %%
import torch.optim as optim

optimizer = optim.SGD(net.parameters(), lr = 0.03)
print(optimizer)
# Out:
# SGD (
# Parameter Group 0
#     dampening: 0
#     lr: 0.03
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )

# %%
print(optimizer.param_groups)
# Out:
# [{'params': [Parameter containing:
# tensor([[ 0.0038, -0.0057]], requires_grad=True), Parameter containing:
# tensor([0.], requires_grad=True)], 'lr': 0.03, 'momentum': 0, 'dampening': 0, 'weight_decay': 0, 'nesterov': False}]

# %%
# 1、为不同的子网络设置不同的学习率（finetune中使用）
optimizer2 = optim.SGD([
    {'params': net.base.parameters()}, 
    {'params': net.subnet1.parameters(), 'lr' : 0.01}
], lr = 0.03)# model.base的学习率采用0.03，subnet1的学习率采用0.01

# 2、动态调整学习率：修改param_groups对应的学习率
for param in optimizer.param_groups:
    param_groups['lr'] *= 0.1

# %% [markdown]
# ## 训练模型

# %%
num_epochs = 3
for epoch in  range(1, num_epochs + 1):
    for X,y in data_iter:
        output = net(X)
        l = loss(output, y.view(-1,1)) # -1 表示x轴的维度又y轴的维度自动决定
        optimizer.zero_grad() # 梯度清零
        l.backward()
        optimizer.step() # 更新所有的参数，在backward之后调用
    print('epoch %d, loss: %f' % (epoch, l.item()))
# Out:
# epoch 1, loss: 0.000441
# epoch 2, loss: 0.000132
# epoch 3, loss: 0.000046

# %%
dense = net[0] #从net获取所需要的层
print(true_w, dense.weight)
print(true_b,dense.bias)
# Out:
# [2, -3.4] Parameter containing:
# tensor([[ 1.9996, -3.4011]], requires_grad=True)
# 4.2 Parameter containing:
# tensor([4.2000], requires_grad=True)
